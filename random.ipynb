# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(1000)
xdata = np.sin(zdata) + 0.1 * np.random.randn(1000)
ydata = np.cos(zdata) + 0.1 * np.random.randn(1000)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='plasma')
plt.show()

# %%
N_sample = 100000

xr = np.random.randn(N_sample)
yr = np.random.randn(N_sample)
zr = np.random.randn(N_sample)

rr = np.sqrt(xr**2 + yr**2 + zr**2)

zdata = xr/rr
xdata = yr/rr
ydata = zr/rr

fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')


ax.scatter3D(xdata*ydata**2, ydata*zdata**2, zdata*xdata**2, c='k', s=0.01)#, cmap='plasma')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.set_box_aspect((1,1,1))

ax.view_init(35, -35)

plt.show()

# %%
N_sample = 100000

xr = np.random.randn(N_sample)
yr = np.random.randn(N_sample)
zr = np.random.randn(N_sample)

rr = np.sqrt(xr**2 + yr**2 + zr**2)

zdata = xr/rr
xdata = yr/rr
ydata = zr/rr

fig = plt.figure(figsize=(12,12))
ax = plt.axes(projection='3d')


ax.scatter3D(xdata**3*ydata*zdata, xdata**1*ydata**2*zdata**1, zdata**3*xdata**1, c='k', s=0.01)#, cmap='plasma')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.set_box_aspect((1,1,1))

ax.view_init(45, -35)


plt.show()

# %%
# c = 1/1+1/1+1/1+....
# an+1 = 1/1+an
# an+1(1+an) = 1
# an+1 + an*an+1 = 1
# c^2 + c - 1 = 0
# c = -1 +/- sqrt(5)/ 2
